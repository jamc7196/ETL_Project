# %% [markdown]
# Students Jorge Alberto Muñozcano Castro, Ernesto Centeno
# ETL Project

# %%
import pandas as pd
import numpy as np

# %%
worldcupsplayers = "WorldCupPlayers.csv"
worldcups1= pd.read_csv(worldcupsplayers)
worldcupmatches = "WorldCupMatches.csv"
worldcups2= pd.read_csv(worldcupmatches)
WorldCups = "WorldCups.csv"
worldcups3= pd.read_csv(WorldCups)

# %%
worldcups1.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
worldcups2.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# ...

# %%
worldcups3.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17        363
# 2           84              15             18      375.7
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %%
CoachesID = worldcups1[["Team Initials","Coach Name","MatchID"]]
CoachesID = CoachesID.rename(columns={"Team Initials":"country_id"})
CoachesID.head()
# Out:
#   country_id           Coach Name  MatchID
# 0        FRA  CAUDRON Raoul (FRA)     1096
# 1        MEX     LUQUE Juan (MEX)     1096
# 2        FRA  CAUDRON Raoul (FRA)     1096
# 3        MEX     LUQUE Juan (MEX)     1096
# 4        FRA  CAUDRON Raoul (FRA)     1096

# %%
CoachesID.to_csv('Coaches.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-26-632fa5ce2dd6> in <module>
# ----> 1 CoachesID.to_csv('Coaches.csv', index = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ...

# %%
CoachesID.count()
# Out:
# country_id    37784
# Coach Name    37784
# MatchID       37784
# dtype: int64

# %%
PlayersID= worldcups1[["Player Name","Shirt Number"]]
Players=PlayersID.drop_duplicates(subset=["Player Name", "Shirt Number"], keep='first')
Players.head()
# Out:
#         Player Name  Shirt Number
# 0       Alex THEPOT             0
# 1   Oscar BONFIGLIO             0
# 2  Marcel LANGILLER             0
# 3      Juan CARRENO             0
# 4   Ernest LIBERATI             0

# %%
PlayersID.to_csv('Players.csv', index = False)

# %%
WC=pd.merge(worldcups1, worldcups2, on="MatchID")
WC
# Out:
#        RoundID_x    MatchID Team Initials               Coach Name Line-up  \
# 0            201       1096           FRA      CAUDRON Raoul (FRA)       S
# 1            201       1096           MEX         LUQUE Juan (MEX)       S
# 2            201       1096           FRA      CAUDRON Raoul (FRA)       S
# 3            201       1096           MEX         LUQUE Juan (MEX)       S
# 4            201       1096           FRA      CAUDRON Raoul (FRA)       S
# ...          ...        ...           ...                      ...     ...
# 39251     255951  300186497           USA  KLINSMANN Juergen (GER)       N
# 39252     255951  300186497           BEL       WILMOTS Marc (BEL)       N
# 39253     255951  300186497           BEL       WILMOTS Marc (BEL)       N
# 39254     255951  300186497           USA  KLINSMANN Juergen (GER)       N
# 39255     255951  300186497           USA  KLINSMANN Juergen (GER)       N
#
#        Shirt Number       Player Name Position Event  Year  ...  \
# ...

# %%
WCroster=WC[["Team Initials", "Player Name"]]
WCroster.head()
# Out:
#   Team Initials       Player Name
# 0           FRA       Alex THEPOT
# 1           MEX   Oscar BONFIGLIO
# 2           FRA  Marcel LANGILLER
# 3           MEX      Juan CARRENO
# 4           FRA   Ernest LIBERATI

# %%
WCroster.to_csv('Country.csv', index = False)

# %%
WCcoaches=WC[["Team Initials","Year", "Coach Name"]]
Coaches = WCcoaches.rename(columns = {"Team Initials":"country_id",'Year':'cup_id',}).drop_duplicates(subset = 'Coach Name').reset_index()
Coaches.head()
# Out:
#    index country_id  cup_id             Coach Name
# 0      0        FRA    1930    CAUDRON Raoul (FRA)
# 1      1        MEX    1930       LUQUE Juan (MEX)
# 2     33        USA    1930       MILLAR Bob (USA)
# 3     34        BEL    1930  GOETINCK Hector (BEL)
# 4     65        YUG    1930  SIMONOVIC Bosko (YUG)

# %%
Coaches.to_csv('Coaches.csv')

# %%
worldcups3.head()

# %%
Worldcups=worldcups3[["Year","Country","Attendance","GoalsScored","QualifiedTeams","MatchesPlayed" ]]
Worldcups=Worldcups.rename(columns={'Year': 'cup_id', 'Country':'Team Initials'})
Worldcups=Worldcups['Team Initials'].replace({'Uruguay': "URU", "Italy":"ITA","France":"FRA","Brazil":"BRA", "Switzerland":"SWI",
                                               "Sweden":"SWE","Chile":"CHI","England":"ENG", "Mexico":"MEX","Germany":"GER","Argentina":"ARG",
                                                "Spain":"SPA","Korea/Japan":"KOR", "South Africa":"RSA"})

# %%
Worldcups

# %%
Worldcups.to_csv('TEAMINITIALS.csv', index = False)

# %%
worldcups2.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# ...

# %%
Matches =worldcups2[["MatchID", "RoundID","Year","Stage","City","Stadium", "Attendance" ]]
Matches=Matches.rename(columns={'Year':'cup_id'}).drop_duplicates(subset = 'MatchID').reset_index()
Matches
# Out:
#      index    MatchID  RoundID  cup_id           Stage         City  \
# 0        0       1096      201    1930         Group 1  Montevideo
# 1        1       1090      201    1930         Group 4  Montevideo
# 2        2       1093      201    1930         Group 2  Montevideo
# 3        3       1098      201    1930         Group 3  Montevideo
# 4        4       1085      201    1930         Group 1  Montevideo
# ..     ...        ...      ...     ...             ...          ...
# 831    831  300186504   255953    2014  Quarter-finals    Brasilia
# 832    832  300186508   255951    2014     Round of 16   Fortaleza
# 833    833  300186459   255951    2014     Round of 16      Recife
# 834    834  300186503   255951    2014     Round of 16   Sao Paulo
# 835    835  300186497   255951    2014     Round of 16    Salvador
#
#                 Stadium  Attendance
# 0               Pocitos      4444.0
# 1        Parque Central     18346.0
# 2        Parque Central     24059.0
# ...

# %%
Matches.to_csv('Matches.csv', index = False)

# %%
P1 = "Players.csv"
P1= pd.read_csv(P1)
P1
# Out:
#             Player Name  Shirt Number
# 0           Alex THEPOT             0
# 1       Oscar BONFIGLIO             0
# 2      Marcel LANGILLER             0
# 3          Juan CARRENO             0
# 4       Ernest LIBERATI             0
# ...                 ...           ...
# 37779           ALVAREZ            19
# 37780           KHEDIRA             6
# 37781            AGUERO            20
# 37782           MUSTAFI            21
# 37783           BASANTA            23
#
# [37784 rows x 2 columns]

# %%
playerdata=WC[["Player Name","MatchID","Shirt Number","Line-up" ]]
playerdata = playerdata.rename(columns = {'Player Name':'Name'}).drop_duplicates(subset = 'Name').reset_index()
playerdata1 = playerdata.rename(columns = {'index':'player_id'})
playerdata1
# Out:
#       player_id              Name    MatchID  Shirt Number Line-up
# 0             0       Alex THEPOT       1096             0       S
# 1             1   Oscar BONFIGLIO       1096             0       S
# 2             2  Marcel LANGILLER       1096             0       S
# 3             3      Juan CARRENO       1096             0       S
# 4             4   Ernest LIBERATI       1096             0       S
# ...         ...               ...        ...           ...     ...
# 7658      34881           S W KIM  300186499            18       N
# 7659      34882        MOGILEVETC  300186499            15       N
# 7660      34883            D W JI  300186499            19       N
# 7661      34884             IONOV  300186499            21       N
# 7662      34885          J H PARK  300186499            22       N
#
# [7663 rows x 5 columns]

# %%
playerdata.to_csv('playersdata.csv', index = False)

# %%
locality = "locality.csv"
locality= pd.read_csv(locality)
roster = pd.merge(WC, locality, on="MatchID")
roster
# Out:
#        RoundID_x    MatchID Team Initials               Coach Name Line-up  \
# 0            201       1096           FRA      CAUDRON Raoul (FRA)       S
# 1            201       1096           FRA      CAUDRON Raoul (FRA)       S
# 2            201       1096           MEX         LUQUE Juan (MEX)       S
# 3            201       1096           MEX         LUQUE Juan (MEX)       S
# 4            201       1096           FRA      CAUDRON Raoul (FRA)       S
# ...          ...        ...           ...                      ...     ...
# 84395     255951  300186497           USA  KLINSMANN Juergen (GER)       N
# 84396     255951  300186497           USA  KLINSMANN Juergen (GER)       N
# 84397     255951  300186497           USA  KLINSMANN Juergen (GER)       N
# 84398     255951  300186497           USA  KLINSMANN Juergen (GER)       N
# 84399     255951  300186497           USA  KLINSMANN Juergen (GER)       N
#
#        Shirt Number       Player Name Position Event  Year  ...  \
# ...

# %%
playerdata2=roster[["MatchID","country_id","Locality" ,"Shirt Number","Line-up" ]]
#playerdata2 = playerdata2.rename(columns = {'Player Name':'Name'}).drop_duplicates(subset = 'Name').reset_index()
playerdata2.head()
# Out:
#    MatchID country_id Locality  Shirt Number Line-up
# 0     1096        FRA     Home             0       S
# 1     1096        MEX     Away             0       S
# 2     1096        FRA     Home             0       S
# 3     1096        MEX     Away             0       S
# 4     1096        FRA     Home             0       S

# %%
roster =pd.merge(playerdata1, playerdata2, on="MatchID")
roster = roster.rename(columns = {'Player Name':'Name'}).drop_duplicates(subset = 'Name').reset_index()
roster=roster[["MatchID","country_id","player_id","Locality" ,"Shirt Number_x","Line-up_y" ]]
roster = roster.rename(columns = {'Shirt Number_x': 'Shirt Number', "Line-up_y":"Line-up"})
roster
# Out:
#         MatchID country_id  player_id Locality  Shirt Number Line-up
# 0          1096        FRA          0     Home             0       S
# 1          1096        FRA          1     Home             0       S
# 2          1096        FRA          2     Home             0       S
# 3          1096        FRA          3     Home             0       S
# 4          1096        FRA          4     Home             0       S
# ...         ...        ...        ...      ...           ...     ...
# 7658  300186499        RUS      34881     Home            18       S
# 7659  300186499        RUS      34882     Home            15       S
# 7660  300186499        RUS      34883     Home            19       S
# 7661  300186499        RUS      34884     Home            21       S
# 7662  300186499        RUS      34885     Home            22       S
#
# [7663 rows x 6 columns]

# %%
roster.to_csv('roster.csv', index = False)
